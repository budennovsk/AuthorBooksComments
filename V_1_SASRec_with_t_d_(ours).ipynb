# %% [markdown]
# <a href="https://colab.research.google.com/github/budennovsk/AuthorBooksComments/blob/master/V_1_SASRec_with_t_d_(ours).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -r "/content/drive/MyDrive/Colab Notebooks/Симбирсофт/recsys/let-it-go-main/requirements_colab.txt" --no-cache-dir --upgrade

# %%
# !pip install clearml==1.18.0 hydra-core==1.3.2 omegaconf==2.3.0 lightning==2.5.0.post0 replay-rec==0.21.1

# %%
from dotenv import load_dotenv
import os

# Загружаем переменные из файла .env
load_dotenv('/content/drive/MyDrive/Colab Notebooks/Симбирсофт/recsys/let-it-go-main/.env')  # Укажите путь к вашему файлу

# Теперь переменные доступны как строки
secret_key = os.getenv('CLEARML_API_SECRET_KEY')  # Получаем как строку
access_key = os.getenv('CLEARML_API_ACCESS_KEY')

# Пример использования
print("Секретный ключ загружен, длина:", len(secret_key or ""))

# %%
! export MPLBACKEND=TkAg

# %%
from clearml import Task

Task.set_credentials(
     api_host="https://api.clear.ml",
     web_host="https://app.clear.ml",
     files_host="https://files.clear.ml",
     key=access_key ,
     secret=secret_key
)

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Симбирсофт/recsys/let-it-go-main/scripts
# !python run.py dataset=beauty use_pretrained_item_embeddings=True train_delta=True
